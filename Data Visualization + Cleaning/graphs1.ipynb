# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\shubh\\Desktop\\BTC-USD.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2475 entries, 0 to 2474
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2475 non-null   object
#  1   Open       2471 non-null   float64
#  2   High       2471 non-null   float64
#  3   Low        2471 non-null   float64
#  4   Close      2471 non-null   float64
#  5   Adj Close  2471 non-null   float64
#  6   Volume     2471 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 135.5+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2471.000000   2471.000000   2471.000000   2471.000000   2471.000000
# mean    7866.536096   8092.743758   7615.020412   7878.405676   7878.405676
# std    11903.190290  12279.204858  11454.898976  11910.456940  11910.456940
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      466.063004    486.855499    459.472504    469.776489    469.776489
# 50%     4384.439941   4470.229980   4269.810059   4382.660156   4382.660156
# 75%     9260.389160   9411.778808   9101.281250   9266.187500   9266.187500
# max    63523.753906  64863.097656  62208.964844  63503.457031  63503.457031
#
#              Volume
# count  2.471000e+03
# mean   1.286143e+10
# std    1.983380e+10
# min    5.914570e+06
# 25%    6.925175e+07
# 50%    4.083980e+09
# 75%    1.929210e+10
# max    3.509679e+11

# %%
df.isna().count()
# Out:
# Date         2475
# Open         2475
# High         2475
# Low          2475
# Close        2475
# Adj Close    2475
# Volume       2475
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date         0
# Open         4
# High         4
# Low          4
# Close        4
# Adj Close    4
# Volume       4
# dtype: int64

# %%
df.dropna()
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2470  2021-06-22  31622.376953  33292.453125  28893.621094  32505.660156
# 2471  2021-06-23  32515.714844  34753.410156  31772.632813  33723.027344
# 2472  2021-06-24  33682.800781  35228.851563  32385.214844  34662.437500
# 2473  2021-06-25  34659.105469  35487.246094  31350.884766  31637.779297
# 2474  2021-06-26  31389.406250  32168.152344  31389.406250  32137.236328
#
#          Adj Close        Volume
# 0       457.334015  2.105680e+07
# ...

# %%
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

# %%
print(df.head())
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2014-09-17 2014-09-17  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 2014-09-18  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 2014-09-19  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 2014-09-20  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 2014-09-21  408.084991  412.425995  393.181000  398.821014
#
#              Adj Close      Volume
# Date
# 2014-09-17  457.334015  21056800.0
# 2014-09-18  424.440002  34483200.0
# 2014-09-19  394.795990  37919700.0
# 2014-09-20  408.903992  36863600.0
# 2014-09-21  398.821014  26580100.0

# %%
plt.plot(df.Open,df.Close)

# %%
plt.plot(df.Open,df.Volume)

# %%
plt.scatter(df.Date,df.Open,color='g')
plt.xlabel("Date")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()

# %%
fig.add_trace(go.Scatter(x=df.Date, y= df.Open,line=dict(color='blue', width=.7)))
fig.add_trace(go.Candlestick(x=df.Date))
#plt.plot(df.Date,df.Open)

yaxis = dict(fixedrange = False)

fig.show()
# Out:
# <div>                            <div id="9ea34dd1-7263-4c4a-8b99-d78096e56849" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea34dd1-7263-4c4a-8b99-d78096e56849")) {                    Plotly.newPlot(                        "9ea34dd1-7263-4c4a-8b99-d78096e56849",                        [{"line":{"color":"blue","width":0.7},"type":"scatter","x":["2014-09-17T00:00:00","2014-09-18T00:00:00","2014-09-19T00:00:00","2014-09-20T00:00:00","2014-09-21T00:00:00","2014-09-22T00:00:00","2014-09-23T00:00:00","2014-09-24T00:00:00","2014-09-25T00:00:00","2014-09-26T00:00:00","2014-09-27T00:00:00","2014-09-28T00:00:00","2014-09-29T00:00:00","2014-09-30T00:00:00","2014-10-01T00:00:00","2014-10-02T00:00:00","2014-10-03T00:00:00","2014-10-04T00:00:00","2014-10-05T
# ...

# %%
candlestick = go.Candlestick(
                            x=df.index,
                            open=df['Open'],
                            high=df['High'],
                            low=df['Low'],
                            close=df['Close']
                            )

# %%
fig1 = go.Figure(data=[candlestick])

# %%
fig1.show()
# Out:
# <div>                            <div id="c3597c52-5e6e-4a77-a476-3d23faf74816" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3597c52-5e6e-4a77-a476-3d23faf74816")) {                    Plotly.newPlot(                        "c3597c52-5e6e-4a77-a476-3d23faf74816",                        [{"close":[457.334015,424.440002,394.79599,408.903992,398.821014,402.152008,435.790985,423.204987,411.574005,404.424988,399.519989,377.181,375.46701,386.944,383.61499,375.071991,359.511993,328.865997,320.51001,330.07901,336.187012,352.940002,365.026001,361.562012,362.299011,378.549011,390.414001,400.869995,394.77301,382.556,383.757996,391.441986,389.54599,382.845001,386.475006,383.15799,358.416992,358.345001,347.270996,354.70401,352.989014,357.618011,335.591003,34
# ...

# %%
plt.bar(df.Date,df.Close)
# Out:
# <BarContainer object of 2475 artists>

# %%
plt.fill_between(df.Date,df.Close)

# %%
plt.hist(df.Open)
# Out:
# (array([1414.,  767.,   90.,   18.,   11.,   54.,   19.,   28.,   34.,
#           36.]),
#  array([  176.897003 ,  6511.5826933, 12846.2683836, 19180.9540739,
#         25515.6397642, 31850.3254545, 38185.0111448, 44519.6968351,
#         50854.3825254, 57189.0682157, 63523.753906 ]),
#  <BarContainer object of 10 artists>)
